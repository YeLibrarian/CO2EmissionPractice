# %% [markdown]
# <a href="https://colab.research.google.com/github/YeLibrarian/CO2EmissionPractice/blob/master/CO2EmissionAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import needed package for data analysis

# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("ggplot")

# %% [markdown]
# Data source:

# %%
data = pd.read_csv('data/edgar-co2-emissions.csv', index_col=0)

# %%
data.head()
# Out:
#              Name          Sector  Year  Emissions
# Code
# AFG   Afghanistan  Power Industry  1970   0.056962
# ALB       Albania  Power Industry  1970   0.600624
# DZA       Algeria  Power Industry  1970   1.645869
# AGO        Angola  Power Industry  1970   0.137546
# AIA      Anguilla  Power Industry  1970   0.000430

# %%
unit = "kiloton" 
# adding a test comment

# %%
dataUSA = data.loc['USA', :]
dataUSA.head()
# Out:
#                Name                       Sector  Year    Emissions
# Code
# USA   United States               Power Industry  1970  1079.968842
# USA   United States                    Buildings  1970   883.543122
# USA   United States                    Transport  1970  1039.772133
# USA   United States  Other industrial combustion  1970  1397.918113
# USA   United States                Other sectors  1970   287.320185

# %%
fig1, ax1 = plt.subplots()

for key, grp in dataUSA.groupby(['Sector']):
    ax1 = grp.plot(ax=ax1, kind='line', x='Year', y='Emissions', label= key)
    plt.legend(loc = 'best')
    plt.xlabel('Year')
    plt.ylabel('Emissions (Kiloton)')
    plt.title('Emissions of CO2 from diffrent sectors in the U.S.')

plt.show()

# %%
##Here's a comment from Ece: this looks great ye!
boxplot = dataUSA.boxplot('Emissions', by='Sector', grid = False, rot = 75)
plt.title("Box plot of CO2 emissions from different sectors in the U.S.")
plt.suptitle("")
plt.ylabel('Emissions (Kiloton)')

plt.show()
